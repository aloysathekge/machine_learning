# %%
import torch

# %%
a=torch.tensor([3])
print(a)
# Out:
# tensor([3])

# %%
b=torch.tensor([
[4,0,1],
[3,1,0],
[4,2,1],
[3,6,2]
])

b.shape
# Out:
# torch.Size([4, 3])

# %%
c=torch.tensor([[6,2],[2,6],[4,1]])
c.shape
# Out:
# torch.Size([3, 2])

# %%
bc= b @ c
print(bc)
# Out:
# tensor([[28],
#         [20],
#         [32],
#         [38]])
